# %%
import json
import datetime
import dateutil
import pytz
import math
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import csv
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np
import nltk
from datetime import datetime
from datetime import timedelta
import dateutil.parser
from gensim import corpora, models
from pprint import pprint
import re
from bs4 import BeautifulSoup

global_warming=['global warming', 'climate change', 'ice', 'years', 'snow', 'arctic', 'scientist', 
                'sea', 'cause', 'ow', 'time', 'show', 'report', 'science', 'data', 'world', 
                'earth', 'environment', 'coverage', 'percent', 'human', 'study', 'satellite', 
                'ipcc', 'epa', 'expert', 'stop', 'fight', 'million', 'people']

climate_change=['climate change', 'global warming', 'ow', 'report', 'ipcc', 'world', 
                'science', 'environment', 'scientist', 'help', 'action', 'impacts', 'arctic', 
                'time', 'australia', 'study', 'caused', 'talk', 'human', 'need', 'people', 'deniers', 
                'huff', 'risk', 'fight', 'years', 'make', 'politics', 'nations', 'carbon']


        
youtuber_list_path="subscriber_network.json"        
comments=[]
with open(youtuber_list_path,'r') as fp:
    youtubers=json.loads(fp.read())["nodes"]
    for you in youtubers:
        for vi in you["video_list"]:
            counter=0
            for comment in vi["comment_list"]:
                cleantext = BeautifulSoup(comment["text"],"html.parser").text
                words=gensim.utils.simple_preprocess(str(cleantext), deacc=True)
                for g in global_warming:
                    if g in words:
                        counter+=1
            print("video: {}, count:{}".format(vi["title"], counter))
# comment_words = list(sent_to_words(comments))
# data_words = list(sent_to_words(comment_words))
# print(data_words[0:10])
# Out:
# video: Planting 20,000,000 Trees, My Biggest Project Ever!, count:63
# video: Important Youtube Announcement (please watch), count:42
# video: Blue's New Superpower - #TeamTrees, count:19
# video: Generations React To MrBeast Planting 20,000,000 Trees (#TeamTrees), count:37
# video: Mokey's Show - Mr. Tree #TeamTrees 🌳, count:12
# video: Using Drones to Plant 20,000,000 Trees, count:55
# video: I Planted INFINITE TREES in Minecraft Hardcore! #TeamTrees, count:33
# video: The Moment @MrBeast, @Mark Rober and TeamTrees planted 20,000,000 Trees!, count:58
# video: The Moment Elon Musk Donated $1,000,000 to TeamTrees - #Treelon, count:45
# video: Live Tree Planting Counter - TeamTrees [20 Million and Beyond!], count:2
# video: The Moment Elon Musk Got Owned and TeamTrees hit 10 Million!, count:56
# video: Plant a Tree, Get a Channel Audit - a #TeamTrees and MrBeast Adventure, count:3
# video: DIY RECYCLE HACKS that will SAVE the world  #TeamTrees, count:29
# video: Planting 20,000,000 Trees Will Actually Have This Impact, count:61
# video: How MrBeast Is Saving the Planet Through #TeamTrees, count:46
# video: Helping Mrbeast Plant 20,000,000 Trees (1 Honk = 1 Tree) #TeamTrees, count:27
# video: We Built a Tree-Planting Cannon #TeamTrees, count:25
# video: #TeamTrees Meme Compilation, count:3
# video: I Tried Planting 20,000,000 Trees (MrBeast & Mark Rober), count:35
# video: Giving $1000 To #TeamTrees If I DO NOT Pull This Pokemon Card!, count:12
# video: #TEAMTREES SONG, count:64
# video: The Tree Tier List #TeamTrees, count:38
# video: The BIGGEST Youtuber Collab In History - Planting 20 Million Trees, count:67
# video: Let's Plant 20 Million Trees To Save The World In Minecraft, count:43
# video: MrBeast called me ( SHOCKING ) LEAKED PHONE CALL! #DramaAlert #TeamTrees, count:19
# video: I plant 20 000 000 Trees in Minecraft (Not Creative), count:18
# video: THEY ACTUALLY DID THAT?! (mad)  #0097, count:18
# video: Can You Plant Trees with Bullets? • #TeamTrees, count:8
# video: THE DOMINO TREE OF LIFE! 🌳 #TeamTrees, count:35
# video: Captain Disillusion on #TeamTrees, count:65
# video: What If Everyone On Earth Planted 1 Tree? - 7,000,000,000 Trees #TeamTrees, count:70
# video: Team Trees Memes, count:41
# video: WHO CAN MAKE THE MOST MONEY IN 24 HOURS (#teamtrees CHALLENGE), count:8
# video: The Try Guys Plant 20 Million Trees (PSA Music Video), count:28
# video: Can You Find Him in This Video? • Hidden in Plain Sight #7 [#TeamTrees], count:30
# video: How MrBeast and Mark Rober Got 20,000,000 Trees Before 2020 | #TeamTrees Data!, count:13
# video: How MrBeast Will FAIL To Plant 20,000,000 Trees | #TeamTrees, count:21
# video: The 6 BIGGEST Moments from the First 24 Hours of #TeamTrees, count:1
# video: How MrBeast and #TeamTrees Are BREAKING Economics, count:4
# video: I Predicted When MrBeast Will Get 20,000,000 Trees Using ECONOMICS | #TeamTrees, count:12
# video: How ECONOMICS Will Save the Forest | #TeamTrees, count:5
# video: Giving $1 to #TeamTrees Every Time I DON'T Get a Hole in One, count:30
# video: How to Plant 20 MILLION TREES - Smarter Every Day 227 #TeamTrees, count:106
# video: How To Plant a Tree, count:26
# video: I Reacted To MrBeast Planting 20,000,000 Trees #TeamTrees, count:31
# video: Can You Plant 20 MILLION TREES?, count:34
# video: MrBeast vs Greta Thunberg actions for the environment | #teamtrees, count:22
# video: VSCO GIRL SAVES THE PLANET!!! #TeamTrees | Petah, count:12
# video: Let’s plant 20 million trees together! #TeamTrees, count:56
# video: I Planted 600,000 Trees In Minecraft #TeamTrees, count:43
# video: Planting a Tree in EVERY STATE for #teamtrees, count:22
# video: I Coded 20,000,000 Trees for #TeamTrees, count:30
# video: Team Trees Explained - How It Works #TeamTrees, count:48
# video: #أنيميشن || قصة الأشجار #TEAMTREES, count:0
# video: What Will 20,000,000 Trees Actually Do? #TeamTrees | Because Science Live!, count:124
# video: Elon Musk TRASHED For Donating 1 Million Trees To #TeamTrees (Obviously), count:88
# video: Can AIRPLANES plant ROCKET trees??? #TeamTrees, count:27
# video: #TeamTrees Hitting 20 Million Trees Planted (2M% Speed Timelapse), count:29
# video: TeamTrees Plants 10 Million Trees (117 Hour Timelapse), count:36
# video: #TeamTrees, count:21
# video: Make a Positive Change 🌱 #TeamTrees, count:34
# video: Making a TASER TREE & Planting 20 MILLION TREES! #TeamTrees, count:61
# video: TREE IMPRESSIONS?! #TeamTrees, count:25
# video: Saving Minecraft ft. CallMeCarson #TeamTrees, count:41
# video: tik toks that are helping to plant 20 MILLION TREES! #teamtrees, count:0
# video: ASMR | #TeamTrees, count:43
# video: Elon Musk Donates $1 Million to MrBeast for #TeamTrees, count:9
# video: THE WHOLE LOBBY WANTS TO BEAM ME! Duos W/ Nate Hill #TeamTrees, count:31
# video: How Reddit Ended up Reacting to Mr Beast's #TeamTrees Project *Team Trees Memes* (20 Million Trees), count:5
# video: How Reddit Reacted to Elon Musk Donating One Million Trees (Team Trees, Treelon, Tobi Lutke, Memes), count:30
# video: Updating Trees to be USEFUL in Minecraft! (#TeamTrees), count:24
# video: Copying Mr Beast for 24 hours! #TeamTrees, count:0
# video: DIY RECYCLE HACKS THAT WILL SAVE THE PLANET! #TeamTrees, count:1
# video: #TeamTrees 🌲 Biggest Donations, count:0
# video: How to make plastic from trees (and not fossil fuels)    #TeamTrees, count:50
# video: 20,000,000 Tree Planting Live Counts #TeamTrees, count:0
# video: A Song for #TeamTrees, count:19
# video: COOKING WITH HOSUH! Oh and also #TeamTrees, count:20
# video: How Much Air Can A Tree Hold? #TeamTrees, count:54
# video: Planting 20,000,000 Trees #teamtrees, count:106
# video: PLANTING 20,000,000 TREES! My Contribution! #TeamTrees, count:27
# video: building a massive minecraft tree for #teamtrees, count:12
# video: #TeamTrees Song by JT Music - "Feel Like Fertilizin'", count:23
# video: Why Mr.Beast Started TeamTrees, count:25
# video: The Weirdest Video You'll Watch Today #TeamTrees, count:24
# video: Terrific Trees: A SciShow #TeamTrees Compilation, count:55
# video: Planting Trees Minecraft Animation #TeamTrees, count:1
# video: The Lorax but only when they say "tree" | #teamtrees, count:3
# video: Planting 00,000,000 Trees, My Smallest Project Ever! #teamtrees, count:1
# video: Planting a tree for #TeamTrees (ft. Mark Rober), count:28
# video: Basically #TeamTrees, count:33
# video: Saving Earth Chan with MEMES and MrBeast #TeamTrees, count:129
# video: Kunnen 20 miljoen bomen het klimaat redden? | UITGEZOCHT #4, count:2
# video: Miljardair doneert een miljoen bomen aan #TeamTrees, count:5
# video: Trees #TeamTrees, count:26
# video: Every Arcade Ticket I Win Plants a Tree! #TeamTrees, count:42
# video: VFX Artist Creates 20,000,000 Trees with CGI, count:0
# video: What If You Made A Song With Only Trees?, count:38
# video: Is #TeamTrees LEGIT? (How does it work?), count:2
# video: I Chopped 100,000 Trees in Forest Nothing #teamtrees, count:13
# video: Can 20 Million Trees Work? No, But You Should Join Anyway!!! #teamtrees, count:119
# video: Planting 20,000,000 TREES In ROBLOX!! #TeamTrees, count:23
# video: TOP 7: Árboles de videojuegos #TeamTrees, count:3
# video: Mokey's Show - Mr. Tree #TeamTrees 🌳| Reaction | Save Tree, count:0
# video: I actually Planted 1,000,000 Trees In Minecraft #teamtrees, count:23
# video: Mokey's Show - Mr. Tree #TeamTrees REACTIONS MASHUP, count:0
# video: Planting A Tree For EVERY Demonetized MK Video!! #TeamTrees, count:14
# video: My Dogs Planting 20,000,000 Trees!! MrBeast #TeamTrees Challenge., count:1
# video: Planting 20,000,000 Trees, Zombies Edition! #TeamTrees, count:5
# video: I Donated $1 to #TeamTrees for Every Virtual Tree Planted, count:7
# video: HELPING to Plant 20 MILLION TREES! #TeamTrees, count:0
# video: Killing the ender dragon in hardcore with a sapling #TeamTrees, count:27
# video: 【寸劇】ただ木と木が話すだけの動画  #TeamTrees, count:0
# video: Enes Batur 20.000.000 Ağaç Diker Mi ? #teamtrees, count:0
# video: Sadzimy 20 milionów drzew #teamtrees, count:0
# video: Reforesting The Ranch Part 8: Fall 2019 Update & #TeamTrees, count:48
# video: Team Trees Storytime, count:17
# video: Every DEATH I plant 5 trees #teamtrees, count:1
# video: Huskies Plant 20,000,000 Trees with MrBeast ! #TeamTrees, count:52
# video: 5 Magic TREE Tricks Revealed! (#TeamTrees), count:13
# video: What is Enginered Wood? Building a Miter Saw Table! #TeamTrees, count:25
# video: Trees #TeamTrees, count:32
# video: Global Warming: Endgame | #TeamTrees, count:6
# video: The Forest Protectors #TeamTrees, count:11
# video: HELPING MR BEAST PLANT 20 MILLION TREES... ❤️🌲 #TeamTrees | Roblox Jailbreak LIVE, count:22
# video: FRUSTRATING!! TRYING TO Make a Sculpture Out of Wood Dust Clay #teamtrees craft challenge, count:29
# video: The Main #TeamTrees YouTubers, count:0
# video: Top 10 #teamtrees donators, count:0
# video: Minden kill után ültettem egy fát | Környezetvédő "kihívás" #TeamTrees [Fortnite], count:1
# video: TeamTrees vs REALITY!!, count:209
# video: A Money Match To Save The Planet! #TeamTrees, count:14
# video: #TeamTrees | A lot of Tree Facts, count:46
# video: This Tree LOVES FIRE (Longleaf Pine) - #TeamTrees Behind the Scenes, count:37
# video: #TeamTrees, count:3
# video: What Would Trees Look Like On Other Planets? #TeamTrees, count:0
# video: Every Tree Pokemon RANKED #TeamTrees, count:16
# video: trees. #TeamTrees, count:36
# video: Let's talk about #TeamTrees...., count:101
# video: Mr Beast Challenged ME To Do This With My BASS :(, count:11
# video: ALBERO DI NATALE FATTO CON BOTTIGLIE DI PLASTICA (DIY) #TeamTrees, count:0
# video: The most important quest!  #TeamTrees, count:0
# video: HELP ME PLANT 20 MILLION TREES IN MINECRAFT! #teamtrees, count:5
# video: Planting 20Million Trees in WorldBox #TeamTrees, count:1
# video: "This Was Terrifying!" Reacting To Mokey's Show - Mr. Tree #TeamTrees, count:2
# video: Mr. Beat Plants a Tree for Mr. Beast #teamtrees, count:11
# video: HOLY CRAP... Did Elon Musk Just… #TeamTrees, count:4
# video: UNFAIR TREES WALKTHROUGH/SPEEDRUN IN 165 SECONDS! #TeamTrees, count:0
# video: UNFAIR TREES OFFICIAL TRAILER! #TeamTrees, count:2
# video: UNFAIR TREES - BEHIND THE SCENES #TeamTrees, count:0
# video: MAKING AN UNFAIR MAP TO SAVE TREES! #TeamTrees, count:2
# video: Planting Trees Where People are Sitting Prank! #TeamTrees, count:17
# video: Bring Me A Shrubbery #TeamTrees, count:40
# video: #TEAMTREES, count:33
# video: I Visited The World's WIDEST Tree for #teamtrees, count:32
# video: Youtuberlar Dünya'yı Kurtarıyor!  #teamtrees, count:0
# video: PLANTING 20 MILLION TREES to SAVE THE WORLD #TeamTrees | Roblox Tree Planting Simulator, count:17
# video: Is #TeamTrees Lying to You?, count:10
# video: Он посадит 20 миллионов деревьев! #teamtrees, count:0
# video: We 3D Printed Treelon! #TeamTrees, count:5
# video: I Matched Your Donations, #TeamTrees, count:8
# video: TREELON! Stringy Wood Filament Fixed with a Heat Gun #TeamTrees, count:20
# video: DIY Mic Flag 3D Printed! #TeamTrees, count:8
# video: #teamtrees: Das steckt hinter der Aktion von MrBeast | WALULIS DAILY, count:4
# video: I Tried Following A Bob Ross Painting Tutorial #TeamTrees, count:18
# video: Mokey's Show - Mr. Tree (Fandub Español Latino) #TeamTrees, count:1
# video: Every Dragon Ball FighterZ Combo Drop = $1000+ donated to #TeamTrees, count:36
# video: RTGame Archive:  Minecraft [PART 24] - #TeamTrees, count:1
# video: MrBeast: How To Say "TEAM TREES!" in 30 Different Languages, count:3
# video: #teamtrees memes, count:0
# video: Satellites You Can Use For FREE!  #teamtrees, count:86
# video: Plant a Tree Now! (Official Video) MrBeast Collab #TeamTrees #NerdOut, count:16
# video: Gardeners of the Galaxy:  #TeamTrees, count:22
# video: noob Girl "SAVES" Minecraft? (#TeamTrees), count:14
# video: Help MrBeast Plant 20 Million Trees  - #TeamTrees, count:7
# video: Building a Realistic, Modern Minecraft Tree House for Mr.Beast #TeamTrees, count:21
# video: TREE CRIMES #teamtrees, count:40
# video: Planting 500 trees cos Mr Beast told me to, count:31
# video: 20,000,000 Trees Isn't Enough #TeamTrees, count:3
# video: Donating to #teamtrees, count:0
# video: #teamtrees but with a coconut, count:8
# video: History of Groot! [Guardians of the Galaxy] #TeamTrees, count:9
# video: help us plant 20 MILLION trees! (#TeamTrees), count:32
# video: #TeamTrees ama burası Türkiye, count:0
# video: #TeamTrees - Pokemon Showdown Fundraiser Livestream!, count:1
# video: #TeamTrees Trees Planted (2 MILLION% Speed Timelapse), count:0
# video: Saying teamtrees.org 20 MILLION TIMES!!!! (more or less) #teamtrees, count:8
# video: Planting 20 MILLION TREES for Mr. Beast & Mark Rober!! 🌲🌲  #TeamTrees, count:6
# video: Indow Helps Plant 20 Million Trees #TeamTrees, count:0
# video: Mokey's Show - Mr. Tree #TeamTrees 🌳 REACTION, count:0
# video: We Planted Trees! #teamtrees, count:0
# video: I donated $1 for every Woods tile in my Empire #TeamTrees, count:10
# video: Planting 20,000,000 trees in Minecraft because MrBeast said to #TeamTrees, count:10
# video: Tree Planting Project|Planting an Oak Tree For #TeamTrees|Part 3, count:0
# video: #TeamTrees Open RCT2 Pine Forest Speed Build, count:1
# video: I Donated my LIFE SAVINGS to #TEAMTREES, count:7
# video: PLANTING 20,000,000 TREES MrBeast! #TeamTrees, count:0
# video: 3D Printed Tree Rubik's Cube #TEAMTREES, count:5
# video: NÉZD MEG NAGYON FONTOS! Az RP Community csatlakozik a #TeamTrees mozgalomhoz!! - RP's Lair, count:2
# video: A Song For #TeamTrees  - "Take a Moment" (feat. Danny P), count:8
# video: I planted 10,000 TREES and reached MAX TREES in Roblox Tree Planting Simulator! #TeamTrees, count:8
# video: שותלים 20 מיליון עצים ומצילים את העולם!!! #TeamTrees, count:2
# video: Planting 20,000,000 trees and HOUSE PLANTS #teamtrees, count:11
# video: 4 kelime ile DOĞAYI KURTAR #teamtrees, count:1
# video: What Alignment is Groot? #TeamTrees #dndecember2019, count:4
# video: #TeamTrees (Minecraft Animation), count:0
# video: ASMR | Bob Ross Inspired Painting ASMR for #TEAMTREES, count:1
# video: Donate now #teamtrees, count:0
# video: Vamos a plantar 20 MILLONES de arboles con MrBeast #Teamtrees - Wefere NEWS, count:3
# video: Screaming pewdiepie #teamtrees, count:1
# video: Legatura dintre copaci si calculatorul cuantic #TeamTrees, count:1
# video: 20,000,000 дерев #TeamTrees, count:0
# video: MrBeast Planting 20,000,000 Trees #TeamTrees, count:2
# video: Helping Mr Beast Plant 20 MILLION Trees! #TeamTrees, count:7
# video: #TeamTrees 🍁 Hug a Tree 🍁 United We Can Plant 20 Million Trees 🍁 Trees by The Learning Station, count:0
# video: Planting 20 MILLION TREES IN PRISON ARCHITECT SIMULATOR -  #TeamTrees + game exploit = Profit??, count:67
# video: RECLAIMED WOOD Toolbox/Planter for #TeamTrees, count:1
# video: Why Stop at 20 Million Trees? Let's Plant 1.2 Trillion! | #TeamTrees, count:7
# video: #teamtrees P4A 2019, count:2
# video: Live Stream #187: Fractal #TeamTrees with Physics, count:1
# video: Best Movie Trees with Mr. Beast #TeamTrees, count:1
# video: I planted a tree to spread awareness about #teamtrees, count:15
# video: TEAMTREES 🌲: la raccolta fondi da $20 MILIONI che impazza su YOUTUBE | Storie, count:0
# video: #TeamTrees is stupid, count:0
# video: I FILLED THEIR ENTIRE BASE WITH TREES! #TeamTrees (Minecraft Trolling), count:4
# video: #TeamTrees / Make A Difference!, count:0
# video: I AM DONATING TO THE #TeamTree CHARITY! BY MrBeast (Mr. Beast), count:0
# video: The MUSHROOM HUNT! [#TeamTrees], count:21
# video: Planting 100 Trees to Help MrBeast #TeamTrees, count:8
# video: Planting 1000 Trees To Help MrBeast | #TeamTrees, count:1
# video: Turkey Morty plants 20 Million Trees #TeamTrees, count:1
# video: ShortVideo: The Tree #teamtrees | Funnymations Season 3, count:0
# video: #teamtrees srilanka, count:2
# video: TEAM TREES -  WHAT'S NEXT AFTER 20 MILLION 🌲🌲🌲?, count:16
# video: LET'S PLANT 20 MILLION BELERICKS! 🌱 #TEAMTREES, count:15
# video: MECH-X4 - Help Save The World #TeamTrees, count:5
# video: #teamtrees DroneSeed's Post-Wildfire Reforestation, count:0
# video: #TeamTrees, count:0
# video: Do YOU wanna be a Superhero? #teamtrees, count:3
# video: Did Supercell BREAK Takedown, or FIX it?! | Mr. Beast Collaboration #TeamTrees, count:41
# video: #82 Planting Christmas Trees: Soil Prep & Planting [plus #teamtrees MrBeast, Mark Rober shoutout], count:1
# video: Hollow Knight - Greenpath (Piano Cover) #teamtrees, count:3
# video: The Moment when RAK donated $100,000 to #TeamTrees | Moment [03], count:0
# video: Tree counter #teamtrees, count:0
# video: #teamtrees znaczy sadzenie drzew, count:0
# video: Quick Farm Tour and Joining Team Trees, count:31
# video: We planted 2000 trees! - The Forest Regenerator 3000 - EPIC! #teamtrees - Forestry Mulcher, count:2
# video: #TEAMTREES Pot-Plant Electric Guitar, count:7
# video: RE: #TeamTrees, count:0
# video: Nechejme stromy žít 🎵 #TeamTrees - aston405 a křišťálový vodopád + Auri (Píseň nejen vánoční, ver.2), count:0
# video: YouTuber pflanzen 20 Millionen Bäume? #TeamTrees, count:1
# video: #TeamTrees - Kingdomcraft #25, count:0
# video: 20 Millionen Bäume pflanzen! - Mit #TeamTrees gegen Waldsterben: Aktion von YouTuber Mr. Beast!, count:1
# video: 20 MILLION TREES! #TEAMTREES LIVE COUNTER, count:0
# video: The Global Warming Cat Disapproves Mr.Beast #TeamTrees, count:0
# video: How to Build a Tree in Minecraft #teamtrees, count:12
# video: 💡Bright Idea's💡 Unboxing Video 5 (#TeamTrees Tree-shirt), count:0
# video: Yandere MC | Day#1| #teamtrees, count:0
# video: Donating $10 for Every Win using Tree Inspired Pokemon | #TeamTrees, count:6
# video: AUFMERKSAMKEIT Für #TEAMTREES in World of Tanks, count:1
# video: TEAM TREES MEMES, count:0
# video: How big are tree genomes? #TeamTrees, count:7
# video: 'The Overstory' and #TeamTrees, count:2
# video: #TeamTrees, count:5
# video: Lego Unikitty is ENDING? #TeamTrees, count:65
# video: Blueberry Plants a Tree [A Small Toontown Short For #TeamTrees], count:1
# video: Pyro From TF2 Tells You To Plant Trees [ASMR] | #TeamTrees, count:3
# video: Destroying Things in VR for Charity #TeamTrees, count:11
# video: How Did #teamtrees Begin?, count:0
# video: Planting an Etymological Tree for #TeamTrees, count:0
# video: #TeamTrees reaches 20 Million !!! Highlights of the journey, count:0
# video: Shaving My Beard For Mr. Beast! Gamers For #TeamTrees, count:41
# video: #TeamTrees Duet with Davie504!!! EPICO, count:3
# video: Mokey's Show - Mr. Tree #TeamTrees 🌳 | Shelos1life REACTION, count:1
# video: Φύτεψε και εσύ! #TeamTrees, count:0
# video: 🌳Planting 20 Million Tree trees in Rust because MrBeast said to #TeamTrees 🌲, count:1
# video: WE PLANTED 100,000 TREES IN MINECRAFT! 😱 // #TeamTrees, count:2
# video: How do leafcutter ants cut leaves off of trees? #TeamTrees, count:2
# video: Hacking an Old Desk to Make it New Again #TeamTrees, count:1
# video: BotW: Fighting Calamity Ganon with only Tree Branches | #TeamTrees, count:33
# video: MrBeast wants me to save trees in Australia #teamtrees, count:0
# video: Helping Mr Beast to Plant 20 million Trees! #TeamTrees, count:9
# video: Planting over 700 trees to help create a Riparian buffer! #teamtrees, count:16
# video: Magic Trees! #TeamTrees [Countryballs Animation], count:11
# video: #TeamTrees: Why do we like trees?, count:2
# video: #TeamTrees, doei 1$ :D, count:0
# video: Save tree algorithms #teamtrees, count:2
# video: Can YouTubers Really SAVE the EARTH??#TeamTrees 🌎, count:8
# video: #teamtrees, count:0
# video: WE plant a tree #teamtrees, count:11
# video: Photosynthesis is WAY Crazier than you Think! | #TeamTrees, count:37
# video: Every time Giorno grew a tree #TeamTrees, count:16
# video: Trees [A Tree Video] #TeamTrees, count:4
# video: Save The TREE Pokémon!! #TeamTrees, count:0
# video: a Poem in Support of #teamtrees and MrBeast, count:0
# video: ¿Plantar 20 MILLONES de árboles sirve de algo? | #Teamtrees, count:5
# video: Datdrop!! ALL profit goes to #TeamTrees, count:18
# video: Magic Trees - magical relaxing (by Rike Games). Mobile Game to support #TeamTrees., count:0
# video: #TeamTrees Michael Fulton - Africa (Cover), count:0
# video: Save da trees !!🌲#TeamTrees, count:0
# video: #TEAMTREES, count:1
# video: Let's Plant 20'000'000 trees - MrBeast Collab #teamtrees, count:1
# video: The Science of Trees (#TeamTrees), count:0
# video: Forest in the Desert? #TeamTrees, count:4
# video: Don't Be A Steve - #TeamTrees, count:0
# video: #TEAMTREES 20 MILLION TREES! | ECOSIA plants trees for YOU USING IT to search the WEB!, count:9
# video: i plant a tree for #teamtrees, count:0
# video: Tree vidoe #TeamTrees, count:0
# video: SAVING TREES | MrBeast #TeamTrees, count:1
# video: Planting $20 Million Trees with Mr Beast & Mark Rober! #TeamTrees, count:4
# video: 20 MILLION TREES in ROBLOX?!... #TeamTrees 🌳, count:0
# video: Roblox Jailbreak Tree Cop! #TeamTrees 🌳, count:3
# video: Save da tres #TeamTrees, count:5
# video: #TeamTrees Minecraft Tree Sapling Placement Sound Slowed Down to 48 Hours, count:1
# video: Let's plant 20 million trees by 2020. #TeamTrees, count:3
# video: Day 1 of donating $1 everyday to #teamtrees till $20,000,000, count:0
# video: Planting Trees In Minecraft To Save The World - #TeamTrees, count:1
# video: #TeamTrees || Planting 20,000,000 Trees On a Server!!!!, count:0
# video: Help us Plant 20,000,000 trees! #TeamTrees, count:0
# video: A Twisted Halloween (Halloween Special) #TeamTrees, count:0
# video: Doctor Reacts to HILARIOUS Medical Memes #9, count:24
# video: Gotta Plant 'Em All! | Pokémon × #TeamTrees parody, count:10
# video: #TeamTrees, count:2
# video: Planting Trees In Animal Crossing For #TeamTrees, count:8
# video: #TeamTrees  |  FPH Cold Open for October 26, 2019, count:1
# video: #TeamTrees | 2D Template | No Plugins | 20 mil trees!!, count:0
# video: #TeamTrees LIVE COUNT! (Angel Menendez vs Angel Menendez Fitness), count:0
# video: About my idea.    #teamtrees, count:6
# video: BE INSPIRED TO PLANT MORE TREES | #TeamTrees | Cinematic Nature + Save The Earth, count:0
# video: Youtuber SELF PROMOTES on #TeamTrees Website, count:2
# video: #teamtrees 24 HOUR CHARITY FURSUIT MAKING LIVESTREAM, count:15
# video: Goose Environmental Rap ¦ #teamtrees, count:2
# video: Ficus Microcarpa || #TeamTrees, count:0
# video: Fortnite Defaults Skins Are Anti #TeamTrees, count:5
# video: Mokey's Show - Mr. Tree #TeamTrees 🌳 Reaction!, count:17
# video: 3 Facts About How Trees Affect Space Travel #TeamTrees, count:7
# video: TeamTrees | In The Branches of An Angel, count:59
# video: Using AI to See Climate Change | #TeamTrees, count:4
# video: 300 SUB GIVEAWAY AND CHANNEL UPDATE -VRchat Funny Moments #Teamtrees, count:0
# video: MTG Top 10: Trees #TeamTrees, count:13
# video: Dear 2045. #saveourplanet #teamtrees #savetheocean, count:6
# video: Malaysia Tanam 50 Juta + Pokok, Tak Ramai Tahu Pun #teamtrees, count:6
# video: #TEAMTREES | TREE OF MIGHT | TFS DRAGON BALL Z ABRIDGED REACTION!, count:9
# video: I Donated 500,000 Trees To Mr. Beast Team Trees Thingy $$$ #teamtrees #SWAG, count:27
# video: Donating $20,000,000 to TeamTrees! #TeamTrees, count:2
# video: 100 Dragons Challenge - 36 | Tree Dragon #TeamTrees, count:2
# video: 20,000,000 Trees w/ Mr. Beast #TeamTrees, count:6
# video: Team Trees | My Opinion #teamtrees, count:21
# video: Chillchief - Team Trees SONG!!, count:0
# video: #TeamTrees Speedpaint - "Taking Root", count:0
# video: Experiment Coca-Cola & Mentos | Volcano Experiment | #TeamTrees, count:0
# video: SAVE THE PLANET WITH MR BEAST! #teamtrees, count:0
# video: Planting 20 Million Trees - A Cinematic Look At Yosemite #teamtrees, count:9
# video: Planting 20 Million trees in minecraft part1 #teamtrees, count:1
# video: Mommy is in the Trees - Unsolved Cold Case | #TeamTrees, count:39
# video: Puggle Plants 20 Million Trees?! #TeamTrees 🌳, count:0
# video: Legendary Mr. Beast Planting Trees - Join #TeamTrees, count:0
# video: #teamtrees RAP!!!!!!!!!, count:0
# video: Winning Trees From a Claw Machine to Plant 20 MILLION #TeamTrees, count:3
# video: content to prove I no oof. #teamtrees #animation #flipaclip #thisisahumanlol, count:0
# video: HELP SAVE THE EARTH! #TeamTrees, count:0
# video: 20 years later after MrBeast plants 20 million trees... #teamtrees, count:6
# video: Help Mr.Beast || #TeamTrees || read description!, count:1
# video: Belittling My Mother to Help Mother Nature #TeamTrees, count:4
# video: Planting 20 million trees in Minecraft *LIVE* #TeamTrees, count:0
# video: Planting 20 million trees in Minecraft *LIVE* #TeamTrees #2, count:0
# video: "Tree" law! Discusssing Gonzales v. Raich #TeamTrees, count:8
# video: Secret Benefits of Trees that make You Happier #TeamTrees | Luke The Orange | MrBeast, count:0
# video: I LOST EVERYTHING GAMBLING in Camp Minecraft! #TeamTrees, count:7
# video: F**K Planet Earth - BIG Deaf (Official Music Video) #teamtrees, count:1
# video: 🌲My new #TeamTrees game! [Play today!]🌲, count:1
# video: Planting 20 Million Trees #TeamTrees, count:0
# video: Replanting a FOREST! #TeamTrees, count:5
# video: #TeamTrees Treant Druid | Saviors of Uldum | Hearthstone, count:13
# video: #TeamTrees 🌳- We CAN save the planet PLANTING TREES  - Planting 20 000 000 Trees, By Mr Beast, count:6
# video: #TeamTrees 🌲 For Honor GREEN Duels - Let's plant 20 Million Trees!, count:4
# video: Planting 20,000,000 Trees #teamtrees, count:3
# video: Should You Replace Your Tech Every Year? #TeamTrees Let's Plant 20 Million Trees!, count:12
# video: Dear 2045 #saveourplanet #savetheocean #teamtrees New Years special read desc, count:2
# video: #TeamTrees 🔴 LIVE Travel Q&A | HeyNadine, count:1
# video: Awesome #teamtrees Level in Super Mario Maker 2, count:3
# video: TINSELTOES IS BACK !! + HAPPY THANKSGIVING !  | LEVEL 285+ #TeamTrees | Fortnite Battle Royale, count:0
# video: #TeamTrees - How Do Trees Grow - Kids STEM, count:3
# video: Top Secret #TeamTrees Day! | Plane Savers | MrBeast, count:40
# video: #TeamTrees: Let's Craft 20 MILLION Trees Together!, count:0
# video: #TeamTrees Ad Appeared in Times Square on a MASSIVE Tower, count:4
# video: Dear 2045..  #Saveourplanet #Saveourocean #Teamtrees, count:2
# video: I'M PART OF #TeamTrees | LETS SAVE THE PLANET!, count:6
# video: #TeamTrees 🔴 We contributed 399 trees as a stream!!, count:0
# video: #TeamTrees Pack (Gwent Custom Cards), count:0
# video: Lazy Stream. News. TCG Openings. #TeamTrees, count:0
# video: #Teamtrees - Help me make a video to support the cause!!, count:3
# video: You've Been Breathing Wrong #teamtrees | Kati Morton, count:70
# video: Лесные пожары в Австралии, России. Что сгорело на самом деле. #TeamTrees. Pray for Australia, count:0
# video: Tree scientists IRL! | #TeamTrees, count:2
# video: The last of my monetization revenue goes to #TeamTrees, count:1
# video: Let's plant 20,000,000 trees - *Mr Beast needs us to help him* #TeamTrees, count:0
# video: Scientists Heard Plants Produce Loud Screams When Damaged! #teamtrees, count:68
# video: Looking at Plant 20Million Trees my Biggest project ever #TeamTrees, count:0
# video: How to Make Drums Samples from Tree Sounds #TeamTrees, count:0
# video: DegenerateCast: #TeamTrees, count:0
# video: #TeamTrees Quest for the GREATEST TREE PUN - T'rees a Company (A Skit/Gaming DatPags Special), count:5
# video: #TeamTrees Madden Mobile Stream - Every Touchdown = 1 Tree Planted, count:2
# video: This is so awesome! Planting 20,000,000 Trees! | #teamtrees, count:0
# video: Announcement: 24 Hour PUBG Team Trees Live Stream #TEAMTREES, count:1
# video: Making a foamy Chemis-Tree for #TeamTrees!, count:5
# video: Hiking With Our Dogs Through 20,000,000 Trees! - #TEAMTREES, count:3
# video: My biggest GIVEAWAY + Collab!! | #teamtrees | #plantykindnessproject, count:23
# video: *TEAM TREES* NEW TH12 Legend League & War Base Review - #teamtrees - Clash of Clans - #67, count:2
# video: Donating 1,612,437 ROBUX to Team Trees from Roblox Tree Planting Simulator!, count:15
# video: Reaction To Blue's New Superpower - #TeamTrees (Made by Alan Becker), count:1
# video: The Most Important Video I'll Ever Make (#teamtrees), count:0
# video: Baby Foxy FNAF SFM Animation - Let's plant 20 milion trees #teamtrees, count:3
# video: 🔴[Live] ZEBRA SQUAD GIVEAWAY ENDS TOMORROW 😲😲😲  [ROBLOX LIVESTREAM]    #TEAMTREES 🌲🌲🌲, count:0
# video: Teamtrees: Especies invasoras, count:3
# video: SciFact: World's Most Dangerous Tree #TeamTrees, count:2
# video: Secret Sixth Finger Found On The Aye-Aye #TeamTrees, count:1
# video: Iceborne Saving Hunters (SOS) and the World #TeamTrees - Monster Hunter World [MR 360], count:8
# video: 18 Hiding Spots Ep 2: #TEAMTREES - 'The Tree'! Effective for Ranked End Circles Apex Legends, count:20
# video: Plants Vs. Zombies donates 500,000 trees to #TeamTrees! (also 17M trees), count:0
# video: How Animals and Trees Help Each Other | Team Trees, count:15
# video: Fishing Competition  #TeamTrees, count:0
# video: Champion League Grind #TeamTrees, count:0
# video: Fishing Competition  #TeamTrees, count:0
# video: Solo/Duo/Sqauds Creative Zone Wars #TeamTrees Arena Solos 1v1s!!, count:0
# video: Solo/Duo/Sqauds Creative Zone Wars #TeamTrees Arena Sqauds, count:0
# video: Lego Team Trees -#teamtrees, count:2
# video: Planting 20,000,000 Trees to save the world #teamtrees, count:13
# video: PUBG SNIPING AT ITS BEST  | VLT SENTINEL | SUPERCHAT TO SUPPORT #TEAMTREES, count:0
# video: 24 Hour Charity Team Trees Livestream - Durthu Tree Only Campaign Part 3, count:7
# video: 24 Hour Charity Team Trees Livestream - Durthu Tree Only Campaign Part 2, count:1
# video: 24 Hour Charity Team Trees Livestream - Durthu Tree Only Campaign Part 1, count:8
# video: Planting trees in Roblox #TeamTrees, count:1
# video: Art Made with Trees: Spire by Andy Goldsworthy | #Teamtrees | Amorsciendi, count:1
# video: Challenge Climate Change #TeamTrees  - Stillnotclicked, count:10
# video: Bloxburg: Treehouse!! #TeamTrees! 78K • Roblox, count:4
# video: Weird Test Gear Classification + Free Poster! + #TeamTrees, count:4
# video: team trees live count #teamtrees, count:0
# video: #teamtrees - A Song (DONATE TODAY!!!), count:0
# video: Teamtrees - scam or real project? Should you believe in Team Trees?, count:60
# video: Why All Animals Need Trees #teamtrees, count:1
# video: 20 MILLION TREES! #TeamTrees, count:0
# video: CedDrawsNear on #TeamTrees, count:0
# video: #teamtrees (roblox), count:0
# video: Autumn Color Phone Photography Vlog & MrBeast #TeamTrees Fundraiser, count:1
# video: Drawing a Tree/ #TeamTrees, count:0
# video: How to make #TeamTrees Cookies, count:0
# video: Tree Review #TeamTrees, count:0
# video: Happy Halloween👻👻👻 (Saving block man go sky block) #teamtrees, count:0
# video: 🌳🔴 Roblox Charity Livestream! Raising Money for #teamtrees And Playing games! Come Join! 🔴🌳, count:0
# video: Galarian Corsola Should NOT Exist! - Pokemon Sword And Shield Theory! #TeamTrees, count:39
# video: Asking University Students What They Think About Climate Change (MrBeast) #TeamTrees, count:30
# video: Real Reason Why Home Builders Destroy So Many Trees 🌲#TeamTrees, count:7
# video: Team Trees Is Stupid | Unsubscribe campaign Ep 7., count:1
# video: The Division 2: Rags to Riches 24-Hour Charity Stream Challenge #TeamTrees | Stream No. 276, count:0
# video: Team Trees! :D #TeamTrees, count:1
# video: #TEAMTREES Roblox -  🔴Live stream🔴 -  20  -  Subscribers Thank You So Much and 1000 views, count:0
# video: #TEAMTREES Roblox -  🔴Live stream🔴 -  20  -  Subscribers Thank You So Much and 1000 views, count:0
# video: #TEAMTREES Roblox -  🔴Live stream🔴 -  Give away  -  Robux 5 viewers, count:0
# video: #TEAMTREES  Random Game! -  🔴Live stream🔴 -  Give away cards  - Free PS4 and XBOX!, count:0
# video: #TEAMTREES Minecraft -  🔴Live stream🔴 -  Give away cards  - Free PS4 and XBOX!, count:0
# video: #TEAMTREES Roblox -  🔴Live stream🔴 -  Give away  -  Robux 5 viewers, count:0
# video: #TEAMTREES Minecraft -  🔴Live stream🔴 -  Give away cards  - Free PS4 and XBOX!, count:0
# video: #TEAMTREES Minecraft -  🔴Live stream🔴 -  Give away cards  - Free PS4 and XBOX!, count:0
# video: #TEAMTREES  Random Game! -  🔴Live stream🔴 -  Give away cards  - Free PS4 and XBOX!, count:0
# video: I made a TeamTrees Deathrun for Mr. Beast... (Fortnite Creative), count:4
# video: #TeamTrees: Eaten alive by Beetles, count:0
# video: SECRET No More - It Will Go Here #TeamTrees, count:3
# video: #TeamTrees and Mr Beast planting 20million trees..., count:0
# video: Saving Trees in Hypixel SkyBlock for #TeamTrees, count:3
# video: Call Of Duty MW Campaign Live - 1 Stream - #TeamTrees, count:0
# video: The Future Of Art Without Trees #Teamtrees, count:4
# video: PART 3 20 MILLION TREES #TEAMTREES CALL OF DUTY CUSTOM ZOMBIES MAP, count:0
# video: Don't Let Earth Become Venus! #TeamTrees, count:1
# video: change da world by planting trees - #TeamTrees, count:1
# video: Stunkles joins #teamtrees, count:2
# video: #TeamTrees Charity LIVESTREAM!, count:0
# video: #teamtrees planting 20million trees, count:0
# video: We need to save all the trees, help us at #TeamTrees, count:2
# video: Top 10 #TeamTrees Hoodies 2019 - Plant A Tree Around The Globe, count:0
# video: lezepo mě pavouk a křičím [TEAM TREES], count:0
# video: Save The Trees! #teamtrees, count:1
# video: bow spammers are destroying the planet! WE NEED HELP! #TeamTrees, count:2
# video: GEM That Rush to MAX for TEAM TREES! Clash of Clans, count:9
# video: Come piantare 20 milioni di alberi - #DdVotr 290 #teamtrees, count:0
# video: The Birds and the Trees - A #TeamTrees Video, count:1
# video: LOLBIT JUMPLOVE TO SAVE THE WORLD #TeamTrees, count:0
# video: How Rockstar Can Screw GTA VI, Streamer Ban Stories, Team Trees Valuable? - Speedrunning Rambles 113, count:24
# video: How I helped planting 20 MILLION TREES | Teamtrees | Getting electrocuted!, count:0
# video: Team Trees, count:0
# video: NBA WEEK 2 3 GAMES Thursday, October 3  | #teamtrees, count:0
# video: I donated to teamtrees..., count:1
# video: Helping Mr Beast plant 20,000,000 trees (#TeamTrees), count:0
# video: Saying "Team Trees" 20,000 to Celebrate Hitting 20,000,000 Trees, count:0
# video: My Anxiety Disorders Are Gone!!! (Paxil) #TEAMTREES Let’s Change The World!!!!!!!, count:2
# video: wholesome planting trees in minecraft #TeamTrees, count:0
# video: Winning jackpots for charity! Team Trees arcade challenge at City Fun Center, count:14
# video: That moment Plants Vs zombies donated 500k to Team Trees (Team Trees 17 mil), count:0
# video: Help mrbeast plant 20 million trees! #Teamtree, count:1
# video: Team Trees! - Kaizir, count:0
# video: Team Trees - A Minecraft Server Commercial, count:0
# video: Tech Story : TeamTrees แคมเปญปลูกต้นไม้ยอดฮิต, count:0
# video: Team Trees Minecraft Competition, count:9
# video: Team Trees ( Mr. Beast, Zach King, Mark Rober ) Tik Tok videos Compilation, count:0
# video: When Elon Musk donated $1,000,000 to team trees [MEME], count:0
# video: Team trees, count:0
# video: Planting 20,000,000 Trees For Team Trees!, count:3
# video: Mr Beast - Live Tree Planting Counter - Team Trees, count:1
# video: Live Tree Planting Counter - TeamTrees [20 Million and Beyond!], count:0
# video: Donate to Team Trees, count:1
# video: NPM Basics - Team Trees Api - Episode 05, count:1
# video: Team trees is not the solution#teamtrees, count:4
# video: MrBeast Plants 20 Million Trees - #teamtrees - LIVE COUNTER, count:0
# video: MrBeast Plants 20 Million Trees - #teamtrees - LIVE COUNTER, count:0
# video: MrBeast Plants 20 Million Trees - #teamtrees - LIVE COUNTER, count:0
# video: MrBeast Plants 20 Million Trees - #teamtrees - LIVE COUNTER, count:0
# video: MrBeast Plants 20 Million Trees - #teamtrees - LIVE COUNTER, count:0
# video: MrBeast Plants 20 Million Trees - #teamtrees - LIVE COUNTER, count:0
# video: MrBeast Plants 20 Million Trees - #teamtrees - LIVE COUNTER, count:0
