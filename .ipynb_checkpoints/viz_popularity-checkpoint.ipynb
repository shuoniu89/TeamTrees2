# %%
from matplotlib import pyplot as plt
from matplotlib import axes
from matplotlib import pyplot
import pandas as pd
import numpy as np
import math
from scipy import stats
import csv
import statistics

from collections import Counter
from collections import defaultdict

result_path = "./KEY/"
df=pd.read_csv(result_path + "final_meta_all_processed - no other.csv")

ref = {"Creation":"CREAT",
       "Participation":"PART",
       "Connection_comment":"CXN-SP", 
       "Connection_game":"CXN-GAM"}

stats=["celebrity", "professional", "amateur"]
df.head()
# Out:
#       video_id                                              title  \
# 0  0hVZOJCYBBM      Important Youtube Announcement (please watch)
# 1  ZNz_tE5VgCY  Generations React To MrBeast Planting 20,000,0...
# 2  Kv3cYKCUoKM  I Planted INFINITE TREES in Minecraft Hardcore...
# 3  lHsymdFIu0U  The Moment @MrBeast, @Mark Rober and TeamTrees...
# 4  Pm9rxDSArhQ  The Moment Elon Musk Donated $1,000,000 to Tea...
#
#    video_length                publish_at  category_id       category  \
# 0           155  2019-12-28T21:00:06.000Z           24  Entertainment
# 1           838  2019-10-25T20:55:13.000Z           24  Entertainment
# 2          1992  2019-10-27T19:45:14.000Z           20         Gaming
# 3           155  2019-12-19T22:48:33.000Z           26  Howto & Style
# 4           109  2019-10-30T02:38:38.000Z           26  Howto & Style
#
#   language live_content                                        description  \
# 0       en         none  I CAN'T BELIEVE WE REACHED OUR GOAL!!!!! YOU G...
# 1       en         none  Support #TeamTrees with us by hitting the DONA...
# 2       en         none  sub pls : http://bit.ly/TxtGm8\r\nDonate to Pl...
# 3       en         none  💲💲💲HOW TO DONATE TO #TEAMTREES💲💲💲\r\nThe most ...
# 4       en         none  💲💲💲HOW TO DONATE TO #TEAMTREES💲💲💲\r\nThe most ...
#
#                                                 tags  ...      merged_tagging  \
# 0                                                NaN  ...  Connection_comment
# 1  "generations react","kids react","teens react"...  ...  Connection_comment
# 2  "Minecraft","dantdm","dan tdm","tdm","dan","fu...  ...  Connection_comment
# 3  "#TeamTrees","TeamTrees","Team Trees","teamtre...  ...  Connection_comment
# 4  "#TeamTrees","TeamTrees","Team Trees","teamtre...  ...  Connection_comment
#
#     quality  creativity  awareness mrbeast arborday  teamtrees_org  \
# 0  4.666667    4.333333   4.333333       y        y              y
# 1  2.666667    2.333333   4.666667       y        y              y
# 2  4.000000    3.666667   4.000000       y        n              y
# 3  4.333333    4.333333   3.666667       y        n              y
# 4  3.666667    3.000000   3.333333       y        y              y
#
#   noteble_youtuber  noteble_entrepreneur  mention_count
# 0                n                     n              3
# 1                y                     n              4
# 2                n                     n              2
# 3                n                     y              3
# 4                n                     y              4
#
# [5 rows x 35 columns]

# %%
x_ticks = ["Celebrity", "Professional", "Amateur"]
colors = ["orange", "mediumseagreen", "steelblue"]
star_size=14  

def make_patch_spines_invisible(ax):
    ax.set_frame_on(True)
    ax.patch.set_visible(False)
    for sp in ax.spines.values():
        sp.set_visible(False)

def sub_fig_multiy(field, y_range1, y_range2, y_range3):
    shift=(0,5,10)
    t=0
    bps=[]
    pos = [1, 2.2, 3]
    
    fig, host = plt.subplots()
    fig.subplots_adjust(right=0.75)
    
    p0, p1, p2 = None, None, None
    plot_var = [p0, p1, p2]

    par1 = host.twinx()
    par2 = host.twinx()
    # Offset the right spine of par2.  The ticks and label have already been
    # placed on the right by twinx above.
    par1.spines["right"].set_position(("axes", .3))
    # Having been created by twinx, par2 has its frame off, so the line of its
    # detached spine is invisible.  First, activate the frame but make the patch
    # and spines invisible.
    make_patch_spines_invisible(par1)
    # Second, show the right spine.
    par1.spines["right"].set_visible(True)
    plots = [host, par1, par2]
    tkw = dict(size=3, width=1.5)
    
    for st in stats: # for each group
        data=[]
        s=df.loc[(df.status==st)][field]
        data.append(s)
        boxprops = dict(linestyle='-', linewidth=2, color=colors[t], label = x_ticks[t])
        plot_var[t]=plots[t].boxplot(data, sym='+', positions=[pos[t]], vert=1,
                                     whis=1.5,widths=0.2, boxprops=boxprops)
        bps.append(plot_var[t])
        plots[t].set_ylabel(st)
        plots[t].yaxis.label.set_color(colors[t])
        plots[t].tick_params(axis='y', colors=colors[t], **tkw)
        t+=1 
    host.set_ylim(y_range1)
    par1.set_ylim(y_range2)
    par2.set_ylim(y_range3)
    plt.xticks([1,2.2,3], x_ticks, fontsize=star_size)
    ax.spines["bottom"].set_position(("data", 0))
    ax.spines["left"].set_position(("axes", .3))
    ax.spines["right"].set_position(("outward", -40))
#     host.legend([bp["boxes"][0] for bp in bps], stats, loc='upper left',mode="expand",ncol=3)


# plt.figure(figsize=(15,6))
plt.subplot(1,3,2)
sub_fig_multiy("vw_ct", (-1e6,5e6), (-1e5, 2e5), (-1e3, 5e3))
plt.title("View count", fontsize=14)
# plt.ylabel("vw_ct", fontsize=star_size)

plt.subplot(1,3,3)
sub_fig_multiy("day_vw", (-.5e5,2e5), (-1e3, 13e3), (-20,100))
plt.title("Day view", fontsize=14, pad = 10)

# plt.ylabel("day_vw", fontsize=star_size)
# Out:
# Text(0.5, 1.0, 'Day view')

# %%
def sub_fig(field, y_range):
    shift=(0,5,10)
    t=0
    bps=[]
    pos = [1]
    for st in stats: # for each group
        data=[]
        s=df.loc[(df.status==st)][field]
        data.append(s)
        boxprops = dict(linestyle='-', linewidth=2, color=colors[t])
        bp=plt.boxplot(data, sym='+', positions=[p+t for p in pos], vert=1, whis=1.5,widths=0.2, boxprops=boxprops)
        bps.append(bp)
        plt.ylim(y_range)
        t+=1  
    plt.xticks([1,2,3], x_ticks, fontsize=star_size)
    ax.legend([bp["boxes"][0] for bp in bps], stats, loc='upper left',mode="expand",ncol=3)
    
plt.figure(figsize=(20,5))
ax=plt.subplot(1,3,1)
sub_fig("quality", (0,6.5))
plt.title("Quality rating", fontsize=14)
plt.ylabel("qual_rt", fontsize=star_size)

ax=plt.subplot(1,3,2)
sub_fig("rel_vw", (-1,10))
plt.title("Relative view score", fontsize=14)
plt.ylabel("(Likes-dislikes)/100 views", fontsize=star_size)

ax=plt.subplot(1,3,3)
sub_fig("rel_like", (-15,35))
plt.title("Relative like score", fontsize=14)
plt.ylabel("Ratio", fontsize=star_size)
# Out:
# Text(0, 0.5, 'Ratio')
