# %%
from matplotlib import pyplot as plt
from matplotlib import axes
from matplotlib import pyplot
import pandas as pd
import numpy as np
import math
from scipy import stats
import csv
import statistics

from collections import Counter
from collections import defaultdict

result_path = "./KEY/"
df=pd.read_csv(result_path + "final_meta_all_processed - no other.csv")

ref = {"Creation":"CREAT",
       "Participation":"PART",
       "Connection":"CXN", 
      }

stats=["celebrity", "professional", "amateur"]
df.head()
# Out:
#       video_id                                              title  \
# 0  0hVZOJCYBBM      Important Youtube Announcement (please watch)
# 1  ZNz_tE5VgCY  Generations React To MrBeast Planting 20,000,0...
# 2  Kv3cYKCUoKM  I Planted INFINITE TREES in Minecraft Hardcore...
# 3  lHsymdFIu0U  The Moment @MrBeast, @Mark Rober and TeamTrees...
# 4  Pm9rxDSArhQ  The Moment Elon Musk Donated $1,000,000 to Tea...
#
#    video_length                publish_at  category_id       category  \
# 0           155  2019-12-28T21:00:06.000Z           24  Entertainment
# 1           838  2019-10-25T20:55:13.000Z           24  Entertainment
# 2          1992  2019-10-27T19:45:14.000Z           20         Gaming
# 3           155  2019-12-19T22:48:33.000Z           26  Howto & Style
# 4           109  2019-10-30T02:38:38.000Z           26  Howto & Style
#
#   language live_content                                        description  \
# 0       en         none  I CAN'T BELIEVE WE REACHED OUR GOAL!!!!! YOU G...
# 1       en         none  Support #TeamTrees with us by hitting the DONA...
# 2       en         none  sub pls : http://bit.ly/TxtGm8\r\nDonate to Pl...
# 3       en         none  💲💲💲HOW TO DONATE TO #TEAMTREES💲💲💲\r\nThe most ...
# 4       en         none  💲💲💲HOW TO DONATE TO #TEAMTREES💲💲💲\r\nThe most ...
#
#                                                 tags  ...  merged_tagging  \
# 0                                                NaN  ...      Connection
# 1  "generations react","kids react","teens react"...  ...      Connection
# 2  "Minecraft","dantdm","dan tdm","tdm","dan","fu...  ...      Connection
# 3  "#TeamTrees","TeamTrees","Team Trees","teamtre...  ...      Connection
# 4  "#TeamTrees","TeamTrees","Team Trees","teamtre...  ...      Connection
#
#     quality  creativity  awareness mrbeast arborday  teamtrees_org  \
# 0  4.666667    4.333333   4.333333       y        y              y
# 1  2.666667    2.333333   4.666667       y        y              y
# 2  4.000000    3.666667   4.000000       y        n              y
# 3  4.333333    4.333333   3.666667       y        n              y
# 4  3.666667    3.000000   3.333333       y        y              y
#
#   noteble_youtuber  noteble_entrepreneur  mention_count
# 0                n                     n              3
# 1                y                     n              4
# 2                n                     n              2
# 3                n                     y              3
# 4                n                     y              4
#
# [5 rows x 35 columns]

# %%
x_ticks = ["Celebrity", "Professional", "Amateur"]
def sub_fig(field, y_range):
    t=0
    colors2=["#F5D54A","#73BAD3","#DD364C","#ABA5A3","#469D8B"] # four styles
    bps=[]
    for k,v in ref.items(): # for each style
        data=[]
        pos=[1,5,9]
        for st in stats: # for each group
            s=df.loc[(df.merged_tagging==k)&(df.status==st)][field]
            data.append(s)
        boxprops = dict(linestyle='-', linewidth=2, color=colors2[t])
        bp=plt.boxplot(data,positions=[p+t for p in pos], sym='+', vert=1, whis=1.5,widths=0.7, boxprops=boxprops)
        bps.append(bp)
        plt.ylim(y_range)
        plt.xticks([2,6,10], x_ticks, fontsize=star_size)
        t+=1    
    ax.legend([bp["boxes"][0] for bp in bps], ref.values(), loc='upper left',ncol=4)

star_size=14    
props = {'connectionstyle':'bar','arrowstyle':'-','shrinkA':1,'shrinkB':1,'linewidth':2}    
plt.figure(figsize=(20,5))
ax=plt.subplot(1,3,1)
sub_fig("quality", (1,6.5))
plt.title("Quality rating", fontsize=14)
plt.ylabel("Rating 1(very low)-5(very high)", fontsize=star_size)
ax.annotate("*", xy=(11.4,5.35), zorder=10, fontsize=star_size)
ax.annotate('', xy=(11,5.2), xytext=(12,5.2), arrowprops=props)
ax.annotate("**", xy=(12.3,5.35), zorder=10, fontsize=star_size)
ax.annotate('', xy=(12,5.2), xytext=(13,5.2), arrowprops=props)
ax.annotate("***", xy=(12.65,5.7), zorder=10, fontsize=star_size)
ax.annotate('', xy=(12,5.4), xytext=(14,5.4), arrowprops=props)
ax.annotate("*", xy=(2.9,5.5), zorder=10, fontsize=star_size)
ax.annotate('', xy=(2,5.2), xytext=(4,5.2), arrowprops=props)

ax=plt.subplot(1,3,2)
sub_fig("rel_vw", (-1,10))
plt.title("Relative view score", fontsize=14)
plt.ylabel("(Likes-dislikes)/100 views", fontsize=star_size)
ax.annotate("**", xy=(7.8,6.3), zorder=10, fontsize=star_size)
ax.annotate('', xy=(7,5.7), xytext=(9,5.7), arrowprops=props)
ax.annotate("***", xy=(7.1,6.9), zorder=10, fontsize=star_size)
ax.annotate('', xy=(6,6), xytext=(9,6), arrowprops=props)

ax=plt.subplot(1,3,3)
sub_fig("rel_like", (-15,35))
plt.title("Relative like score", fontsize=14)
plt.ylabel("Ratio", fontsize=star_size)
ax.annotate("*", xy=(7.9,24.5), zorder=10, fontsize=star_size)
ax.annotate('', xy=(7,22), xytext=(9,22), arrowprops=props)

plt.savefig(result_path + "viz_qual_rt.png")
